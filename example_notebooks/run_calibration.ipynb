# %% [markdown]
# # Python Glacier Evolution individual glacier calibration demo

# %% [markdown]
# Brandon Tober, David Rounce<br>
# Carnegie Mellon University<br>
# 20241220<br> <br>
# The onbjective of this notebook is to demonstrate the various calibration options of PyGEM.
# Regardless of the calibration option selected, a *<rgi_glacier_number>-modelprms_dict.json* file should be created within **~/pygem_data/Output/calibration/** which can then be used to run simulations. See [PyGEM's readthedocs](https://pygem.readthedocs.io/en/latest/calibration_options.html) for details on the various calibration options.
# <br> <br>
# The calibration options are each demonstrated below. Note, we recommend using the [MCMC](#MCMC-target) calibration option
# (Rounce et al. [2020a](https://www.cambridge.org/core/journals/journal-of-glaciology/article/quantifying-parameter-uncertainty-in-a-largescale-glacier-evolution-model-using-bayesian-inference-application-to-high-mountain-asia/61D8956E9A6C27CC1A5AEBFCDADC0432), [2020b](https://www.frontiersin.org/articles/10.3389/feart.2019.00331/full), [2023](https://www.science.org/doi/10.1126/science.abo1324)) as this enables the user to quantify the uncertainty associated with the model parameters in the simulations; however, it is very computationally expensive. The methods from [Huss and Hock (2015)](https://www.frontiersin.org/articles/10.3389/feart.2015.00054/full) provide a computationally cheap alternative.

# %%
### imports ###
import os, sys, glob, json
# pygem imports
import pygem.setup.config as config
# check for config
config.ensure_config()
# read the config
pygem_prms = config.read_config()   # NOTE: ensure that your root path in ~/PyGEM/config.yaml points to
                                    # the appropriate location. If any errors occur, check this first.
rootpath=pygem_prms['root']

# %%
# specify glacier numbember (RGI6 id), we'll run Kaskawulsh in the Canadian Yukon
glac_no = 1.16201
# specify some variables that will remain constant for each calibration option
yr0=2000    # reference period startyear
yr1=2019    # reference period endyear
gcm='ERA5'  # reference period GCM

# %% [markdown]
# ## HH2015
# The calibration option **HH2015** follows the calibration steps from [Huss and Hock (2015)](https://www.frontiersin.org/articles/10.3389/feart.2015.00054/full). Specifically, the precipitation factor is initially adjusted between 0.8-2.0. If agreement between the observed and modeled mass balance is not reached, then the degree-day factor of snow is adjusted between 1.75-4.5 mm $d^{-1}$ $K^{-1}$. Note that the ratio of the degree-day factor of ice to snow is set to 2, so both parameters are adjusted simultaneously. Lastly, if agreement is still not achieved, then the temperature bias is adjusted.

# %%
# call run calibration
calib_opt = 'HH2015'
# !run_calibration -rgi_glac_number {glac_no} -ref_startyear {yr0} -ref_endyear {yr1} -ref_gcm_name {gcm} -option_calibration {calib_opt}
# Out:
# Processing: ERA5
# 1 glaciers in region 1 are included in this model run: ['16201']
# This study is focusing on 1 glaciers in region [1]
# ERA5 : RGI60-01.16201
# 2024-12-20 13:07:51: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:07:51: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:07:51: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:07:51: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:07:51: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:07:51: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# Total processing time: 1.3395397663116455 s

# %%
# check the output - the parameter dictionary output should now have an `HH2015` key
glacier_str = str(glac_no)
reg = glacier_str.split('.')[0].zfill(2)
calib_path = f"{pygem_prms['root']}/Output/calibration/{reg}/{glacier_str}-modelprms_dict.json"

with open(calib_path, 'r') as f:
    modelprms_dict = json.load(f)

print(modelprms_dict['HH2015'])
# Out:
# {'kp': [0.8], 'tbias': [2.5833985612587504], 'ddfsnow': [0.0045], 'ddfice': [0.0064285714285714285], 'tsnow_threshold': [1], 'precgrad': [0.0001], 'mb_mwea': [-0.34288135872240705], 'mb_obs_mwea': [-0.3450898212087977], 'mb_obs_mwea_err': [0.0686996250912996]}

# %% [markdown]
# ## HH2015mod
# The calibration option **HH2015mod** is a modification of the calibration steps from [Huss and Hock (2015)](https://www.frontiersin.org/articles/10.3389/feart.2015.00054/full) that are used to generate the prior distributions for the MCMC methods [(Rounce et al. 2020a)](https://www.cambridge.org/core/journals/journal-of-glaciology/article/quantifying-parameter-uncertainty-in-a-largescale-glacier-evolution-model-using-bayesian-inference-application-to-high-mountain-asia/61D8956E9A6C27CC1A5AEBFCDADC0432). Since the MCMC methods used degree-day factors of snow based on previous studies, only the precipitation factor and temperature bias are calibrated. The precipitation factor varies from 0.5-3 and if agreement is not reached between the observed and modeled mass balance, then the temperature bias is varied. Note the limits on the precipitation factor are estimated based on a rough estimate of the precipitation factors needed for the modeled winter mass balance of reference glacier to match the observations.

# %%
# call run_calibration
calib_opt = 'HH2015mod'
# !run_calibration -rgi_glac_number {glac_no} -ref_startyear {yr0} -ref_endyear {yr1} -ref_gcm_name {gcm} -option_calibration {calib_opt}
# Out:
# Processing: ERA5
# 1 glaciers in region 1 are included in this model run: ['16201']
# This study is focusing on 1 glaciers in region [1]
# ERA5 : RGI60-01.16201
# 2024-12-20 13:07:55: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:07:55: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:07:55: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:07:55: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:07:55: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:07:55: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# Total processing time: 2.140866756439209 s

# %%
# check the output - the parameter dictionary output should now have an `HH2015mod` key
with open(calib_path, 'r') as f:
    modelprms_dict = json.load(f)

print(modelprms_dict['HH2015mod'])
# Out:
# {'kp': [0.5099657285202738], 'tbias': [1.9944306735663409], 'ddfsnow': [0.0041], 'ddfice': [0.005857142857142858], 'tsnow_threshold': [1], 'precgrad': [0.0001], 'mb_mwea': [-0.3470834166543658], 'mb_obs_mwea': [-0.3450898212087977], 'mb_obs_mwea_err': [0.0686996250912996]}

# %% [markdown]
# ## Emulator - applying HH2015mod
# The calibration option **emulator** creates an independent emulator for each glacier that is derived by performing 100 present-day simulations based on randomly sampled model parameter sets and then fitting a Gaussian Process to these parameter-response pairs. This model replaces the mass balance model within the MCMC sampler, which tests showed reduces the computational expense by two orders of magnitude.
#
# ```{note}
# Note: The 'emulator' calibration option needs to be run before the ‘MCMC’ option.
# ```

# %%
# call run_calibration
calib_opt = 'emulator'
# !run_calibration -rgi_glac_number {glac_no} -ref_startyear {yr0} -ref_endyear {yr1} -ref_gcm_name {gcm} -option_calibration {calib_opt}
# Out:
# Processing: ERA5
# 1 glaciers in region 1 are included in this model run: ['16201']
# This study is focusing on 1 glaciers in region [1]
# ERA5 : RGI60-01.16201
# 2024-12-20 13:07:59: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:07:59: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:07:59: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:00: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:00: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:00: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# Total processing time: 14.270448923110962 s

# %%
# check the output - the parameter dictionary output should now have an `emulator` key
with open(calib_path, 'r') as f:
    modelprms_dict = json.load(f)

print(modelprms_dict['emulator'])
# Out:
# {'kp': [0.5], 'tbias': [1.96875], 'ddfsnow': [0.0041], 'ddfice': [0.005857142857142858], 'tsnow_threshold': [1], 'precgrad': [0.0001], 'mb_mwea': [-0.34840228237159837], 'mb_obs_mwea': [-0.3450898212087977], 'mb_obs_mwea_err': [0.0686996250912996]}

# %% [markdown]
# ```{note}
# Note: The 'emulator' calibration option stores all simulations used to derive the emulator in ~/pygem_data/Output/emulator/sims/
# ```

# %%
# %%bash -s "$rootpath" "$reg" "$glac_no"
# head $1/Output/emulator/sims/$2/$3-100_emulator_sims.csv
# Out:
# tbias,kp,ddfsnow,mb_mwea,nbinyrs_negmbclim
# -5.566601438741234,1.0,0.0041,1.025746554363591,12.0
# -5.566601438741234,6.638352067993811,0.0041,6.860549923861252,0.0
# -5.066601438741234,1.0,0.0041,1.0183793934027536,34.0
# -4.566601438741234,1.0,0.0041,1.0083579654616297,87.0
# -4.066601438741234,1.0,0.0041,0.9945963009984929,196.0
# -3.566601438741234,1.0,0.0041,0.9762401874114817,352.0
# -3.066601438741234,1.0,0.0041,0.9527362187847419,536.0
# -2.566601438741234,1.0,0.0041,0.9225125738834461,759.0
# -2.066601438741234,1.0,0.0041,0.8854360392323131,1013.0

# %% [markdown]
# <a id="MCMC-target"></a>
#
# ## Bayesian inference calibration using Markov Chain Monte Carlo methods
# The calibration option **MCMC** is the recommended option. Details of the methods are provided by Rounce et al. ([2020a](https://www.cambridge.org/core/journals/journal-of-glaciology/article/quantifying-parameter-uncertainty-in-a-largescale-glacier-evolution-model-using-bayesian-inference-application-to-high-mountain-asia/61D8956E9A6C27CC1A5AEBFCDADC0432), [2023](https://www.science.org/doi/10.1126/science.abo1324)). In short, Bayesian inference is performed using Markov Chain Monte Carlo (MCMC) methods, which requires a mass balance observation (including the uncertainty represented by a standard deviation) and prior distributions. In an ideal world, we would have enough data to use broad prior distributions (e.g., uniform distributions), but unfortunately the model is overparameterized meaning there are an infinite number of parameter sets that give us a perfect fit. We therefore must use an empirical Bayes approach by which we use a simple optimization scheme (the **HH2015mod** calibration option) to generate our prior distributions at the regional scale, and then use these prior distributions for the Bayesian inference. The prior distribution for the degree-day factor is based on previous data ([Braithwaite 2008](https://www.cambridge.org/core/journals/journal-of-glaciology/article/temperature-and-precipitation-climate-at-the-equilibriumline-altitude-of-glaciers-expressed-by-the-degreeday-factor-for-melting-snow/6C2362F61B7DE7F153247A039736D54C)), while the temperature bias and precipitation factor are derived using a simple optimization scheme based on each RGI Order 2 subregion. The temperature bias assumes a normal distribution and the precipitation factor assumes a gamma distribution to ensure positivity. Glacier-wide winter mass balance data ([WGMS 2020](https://wgms.ch/data_databaseversions/)) are used to determine a reasonable upper-level constraint for the precipitation factor for the simple optimization scheme.
#
# The MCMC methods thus require several steps. These steps can be skipped if the **emulator** calibration option has already been run for the region of interest and regional priors have been defined - if the file *~/pygem_data/Output/calibration/priors_region.csv* exists.<br>
# 1. run the calibration with <em>option_calibration = 'emulator'</em> (as shown in previous cell). This creates an emulator that helps speed up the simulations within the MCMC methods and helps generate an initial calibration to generate the regional priors. Run this initial calibration:
#     ```
#     !run_calibration -option_calibration emulator
#     ```
# 2. The regional priors are then determined by running the following:
#     ```
#     !run_mcmc_prior
#     ```
#     This will output a .csv file that has the distributions for the temperature bias and precipitation factors for each Order 2 RGI subregion. This file is located in `~/pygem_data/Output/calibration/`
#     <br><br>
# 3. Once the regional priors are set, the MCMC methods can be performed.
#     ```
#     !run_calibration -option_calibration MCMC
#     ```
#     In order to reduce the file size, the parameter sets are thinned by a factor of 10. This is reasonable given the correlation between subsequent parameter sets during the Markov Chain, but can be adjusted if thinning is not desired (change `[calib]['MCMC_params']['thin_interval']` to 1 in the *~/PyGEM/config.yaml* configuration file).
#
# ```{note}
# Note: 'MCMC_fullsim' is another calibration option that runs full model simulations within the MCMC methods instead of using the emulator. It is computationally very expensive but allows one to assess the emulators impact on the MCMC methods.
# ```

# %%
# to demonstrate the MCMC calibration steps, we'll select a small region - this may still take some time if OGGM's preprocessed data is not yet downloaded
# recall we need to first run the 'emulator' calibration option for an entire RGI region to develop regional priors
# we'll also run in parallel to speed things up a bit
calib_opt = 'emulator'
region = 6
num_cores=8     # change depending on how many cores you have
# !run_calibration -rgi_region01 {region} -ref_startyear {yr0} -ref_endyear {yr1} -ref_gcm_name {gcm} -option_calibration {calib_opt} -ncores {num_cores}
# Out:
# This study is focusing on 568 glaciers in region [6]
# Processing: ERA5
# Processing in parallel with 8 cores...
# 71 glaciers in region 6 are included in this model run: ['00001', '00009', '00017', '00025', '00033', '00041', '00049', '00057', '00065', '00073', '00081', '00089', '00097', '00105', '00113', '00121', '00129', '00137', '00145', '00153', '00161', '00169', '00177', '00185', '00193', '00201', '00209', '00217', '00225', '00233', '00241', '00249', '00257', '00265', '00273', '00281', '00289', '00297', '00305', '00313', '00321', '00329', '00337', '00345', '00353', '00361', '00369', '00377', '00385', '00393'] and more
# 71 glaciers in region 6 are included in this model run: ['00002', '00010', '00018', '00026', '00034', '00042', '00050', '00058', '00066', '00074', '00082', '00090', '00098', '00106', '00114', '00122', '00130', '00138', '00146', '00154', '00162', '00170', '00178', '00186', '00194', '00202', '00210', '00218', '00226', '00234', '00242', '00250', '00258', '00266', '00274', '00282', '00290', '00298', '00306', '00314', '00322', '00330', '00338', '00346', '00354', '00362', '00370', '00378', '00386', '00394'] and more
# This study is focusing on 71 glaciers in region [6]
# 71 glaciers in region 6 are included in this model run: ['00003', '00011', '00019', '00027', '00035', '00043', '00051', '00059', '00067', '00075', '00083', '00091', '00099', '00107', '00115', '00123', '00131', '00139', '00147', '00155', '00163', '00171', '00179', '00187', '00195', '00203', '00211', '00219', '00227', '00235', '00243', '00251', '00259', '00267', '00275', '00283', '00291', '00299', '00307', '00315', '00323', '00331', '00339', '00347', '00355', '00363', '00371', '00379', '00387', '00395'] and more
# This study is focusing on 71 glaciers in region [6]
# This study is focusing on 71 glaciers in region [6]
oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:26: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:26: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.icethickness: (RGI60-06.00001) consensus_gridded
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.icethickness: (RGI60-06.00008) consensus_gridded
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.mbdata: (RGI60-06.00001) mb_df_to_gdir
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.mbdata: (RGI60-06.00008) mb_df_to_gdir
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.icethickness: (RGI60-06.00007) consensus_gridded
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.icethickness: (RGI60-06.00004) consensus_gridded
# ERA5 : RGI60-06.00003
# 2024-12-20 13:08:26: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:26: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:26: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.mbdata: (RGI60-06.00007) mb_df_to_gdir
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.mbdata: (RGI60-06.00004) mb_df_to_gdir
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# ERA5 : RGI60-06.00005
# 2024-12-20 13:08:26: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:26: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:26: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:26: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.icethickness: (RGI60-06.00003) consensus_gridded
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.mbdata: (RGI60-06.00003) mb_df_to_gdir
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.icethickness: (RGI60-06.00005) consensus_gridded
# 2024-12-20 13:08:26: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:26: pygem.shop.mbdata: (RGI60-06.00005) mb_df_to_gdir
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00001) debris_to_gdir
# 2024-12-20 13:08:27: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00001: Error: debris directory does not exist.
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00001) debris_binned
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00007) debris_to_gdir
# 2024-12-20 13:08:27: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00007: Error: debris directory does not exist.
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00007) debris_binned
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00004) debris_to_gdir
# 2024-12-20 13:08:27: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00004: Error: debris directory does not exist.
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00004) debris_binned
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00008) debris_to_gdir
# 2024-12-20 13:08:27: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00008: Error: debris directory does not exist.
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00008) debris_binned
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00003) debris_to_gdir
# 2024-12-20 13:08:27: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00003: Error: debris directory does not exist.
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00003) debris_binned
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00005) debris_to_gdir
# 2024-12-20 13:08:27: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00005: Error: debris directory does not exist.
# 2024-12-20 13:08:27: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:27: pygem.shop.debris: (RGI60-06.00005) debris_binned
# 2024-12-20 13:08:34: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:34: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:34: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:34: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:34: pygem.shop.icethickness: (RGI60-06.00016) consensus_gridded
# 2024-12-20 13:08:34: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:34: pygem.shop.mbdata: (RGI60-06.00016) mb_df_to_gdir
# 2024-12-20 13:08:34: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:34: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:34: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:34: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:34: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:34: pygem.shop.icethickness: (RGI60-06.00009) consensus_gridded
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.mbdata: (RGI60-06.00009) mb_df_to_gdir
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.icethickness: (RGI60-06.00013) consensus_gridded
# 2024-12-20 13:08:35: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:35: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:35: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:35: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:35: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:35: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.mbdata: (RGI60-06.00013) mb_df_to_gdir
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00016) debris_to_gdir
# 2024-12-20 13:08:35: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00016: Error: debris directory does not exist.
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00016) debris_binned
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.icethickness: (RGI60-06.00015) consensus_gridded
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.mbdata: (RGI60-06.00015) mb_df_to_gdir
# 2024-12-20 13:08:35: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:35: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:35: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:35: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:35: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:35: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.icethickness: (RGI60-06.00011) consensus_gridded
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.mbdata: (RGI60-06.00011) mb_df_to_gdir
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00009) debris_to_gdir
# 2024-12-20 13:08:35: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00009: Error: debris directory does not exist.
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00009) debris_binned
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00013) debris_to_gdir
# 2024-12-20 13:08:35: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00013: Error: debris directory does not exist.
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00013) debris_binned
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00015) debris_to_gdir
# 2024-12-20 13:08:35: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00015: Error: debris directory does not exist.
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00015) debris_binned
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00011) debris_to_gdir
# 2024-12-20 13:08:35: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00011: Error: debris directory does not exist.
# 2024-12-20 13:08:35: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:35: pygem.shop.debris: (RGI60-06.00011) debris_binned
# 2024-12-20 13:08:36: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:36: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:36: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:36: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:36: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:36: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:37: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:37: pygem.shop.icethickness: (RGI60-06.00012) consensus_gridded
# 2024-12-20 13:08:37: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:37: pygem.shop.mbdata: (RGI60-06.00012) mb_df_to_gdir
# 2024-12-20 13:08:37: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:37: pygem.shop.debris: (RGI60-06.00012) debris_to_gdir
# 2024-12-20 13:08:37: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00012: Error: debris directory does not exist.
# 2024-12-20 13:08:37: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08:37: pygem.shop.debris: (RGI60-06.00012) debris_binned
# 2024-12-20 13:08:40: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:40: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:40: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:40: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:40: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:40: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:41: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:41: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:41: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:41: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:41: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:41: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:41: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:41: pygem.shop.icethickness: (RGI60-06.00021) consensus_gridded
# 2024-12-20 13:08:41: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:41: pygem.shop.mbdata: (RGI60-06.00021) mb_df_to_gdir
# 2024-12-20 13:08:41: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:08:41: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:08:41: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:08:41: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:08:41: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:08:41: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:08:41: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:08:41: pygem.shop.icethickness: (RGI60-06.00017) consensus_gridded
# 2024-12-20 13:08:41: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:08:41: pygem.shop.mbdata: (RGI60-06.00017) mb_df_to_gdir
# 2024-12-20 13:08:42: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:08:42: pygem.shop.debris: (RGI60-06.00021) debris_to_gdir
# 2024-12-20 13:08:42: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00021: Error: debris directory does not exist.
# 2024-12-20 13:08:42: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:08
oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:18:29: pygem.shop.icethickness: (RGI60-06.00555) consensus_gridded
# 2024-12-20 13:18:29: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:18:29: pygem.shop.mbdata: (RGI60-06.00555) mb_df_to_gdir
# 2024-12-20 13:18:30: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:18:30: pygem.shop.debris: (RGI60-06.00555) debris_to_gdir
# 2024-12-20 13:18:30: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00555: Error: debris directory does not exist.
# 2024-12-20 13:18:30: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:18:30: pygem.shop.debris: (RGI60-06.00555) debris_binned
# 2024-12-20 13:18:32: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:18:32: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:18:32: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:18:32: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:18:32: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:18:32: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:18:33: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:18:33: pygem.shop.icethickness: (RGI60-06.00561) consensus_gridded
# 2024-12-20 13:18:33: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:18:33: pygem.shop.mbdata: (RGI60-06.00561) mb_df_to_gdir
# 2024-12-20 13:18:33: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:18:33: pygem.shop.debris: (RGI60-06.00561) debris_to_gdir
# 2024-12-20 13:18:33: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00561: Error: debris directory does not exist.
# 2024-12-20 13:18:33: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:18:33: pygem.shop.debris: (RGI60-06.00561) debris_binned
# 2024-12-20 13:18:34: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:18:34: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:18:34: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:18:34: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:18:34: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:18:34: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:18:34: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:18:34: pygem.shop.icethickness: (RGI60-06.00567) consensus_gridded
# 2024-12-20 13:18:34: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:18:34: pygem.shop.mbdata: (RGI60-06.00567) mb_df_to_gdir
# 2024-12-20 13:18:34: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:18:34: pygem.shop.debris: (RGI60-06.00567) debris_to_gdir
# 2024-12-20 13:18:34: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00567: Error: debris directory does not exist.
# 2024-12-20 13:18:34: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:18:34: pygem.shop.debris: (RGI60-06.00567) debris_binned
# 2024-12-20 13:18:36: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2024-12-20 13:18:36: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2024-12-20 13:18:36: oggm.cfg: Multiprocessing: using all available processors (N=10)
# 2024-12-20 13:18:36: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2024-12-20 13:18:36: oggm.cfg: PARAMS['dl_verify'] changed from `False` to `True`.
# 2024-12-20 13:18:36: oggm.cfg: PARAMS['use_multiple_flowlines'] changed from `True` to `False`.
# 2024-12-20 13:18:36: oggm.workflow: Execute entity tasks [consensus_gridded] on 1 glaciers
# 2024-12-20 13:18:36: pygem.shop.icethickness: (RGI60-06.00563) consensus_gridded
# 2024-12-20 13:18:36: oggm.workflow: Execute entity tasks [mb_df_to_gdir] on 1 glaciers
# 2024-12-20 13:18:36: pygem.shop.mbdata: (RGI60-06.00563) mb_df_to_gdir
# 2024-12-20 13:18:37: oggm.workflow: Execute entity tasks [debris_to_gdir] on 1 glaciers
# 2024-12-20 13:18:37: pygem.shop.debris: (RGI60-06.00563) debris_to_gdir
# 2024-12-20 13:18:37: pygem.shop.debris: AssertionError occurred during task debris_to_gdir on RGI60-06.00563: Error: debris directory does not exist.
# 2024-12-20 13:18:37: oggm.workflow: Execute entity tasks [debris_binned] on 1 glaciers
# 2024-12-20 13:18:37: pygem.shop.debris: (RGI60-06.00563) debris_binned
# Total processing time: 626.6337039470673 s

# %% [markdown]
# TO BE CONTINUED...
